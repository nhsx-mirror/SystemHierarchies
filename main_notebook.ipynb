# %%
import plotly.express as px
from plotly import graph_objects as go
import pandas as pd
#import chart_studio.tools as tls

# %%
df_gp = pd.read_csv('/Users/muhammad-faaiz.shanawas/Documents/GitHub/SystemHierarchies/data/gp-reg-pat-prac-map.csv')
list_of_ccgs = df_gp['CCG_CODE'].unique()
num_of_ccgs = len(list_of_ccgs)

# %%
list_of_pcns = df_gp['PCN_NAME'].unique()
num_of_pcns = len(list_of_pcns)

# %%
list_of_stps = df_gp['STP_NAME'].unique()
num_of_stps = len(list_of_stps)

# %%
df_gp_cut = df_gp[['PRACTICE_NAME', 'PCN_NAME', 'CCG_NAME', 'STP_NAME', 'COMM_REGION_NAME']]
df_gp
# Out:
#            PUBLICATION EXTRACT_DATE PRACTICE_CODE  \
# 0     GP_PRAC_PAT_LIST    01Jan2022        A81001
# 1     GP_PRAC_PAT_LIST    01Jan2022        A81002
# 2     GP_PRAC_PAT_LIST    01Jan2022        A81004
# 3     GP_PRAC_PAT_LIST    01Jan2022        A81005
# 4     GP_PRAC_PAT_LIST    01Jan2022        A81006
# ...                ...          ...           ...
# 6522  GP_PRAC_PAT_LIST    01Jan2022        Y06810
# 6523  GP_PRAC_PAT_LIST    01Jan2022        Y07014
# 6524  GP_PRAC_PAT_LIST    01Jan2022        Y07016
# 6525  GP_PRAC_PAT_LIST    01Jan2022        Y07020
# 6526  GP_PRAC_PAT_LIST    01Jan2022        Y07059
#
#                                  PRACTICE_NAME PRACTICE_POSTCODE PCN_CODE  \
# 0                          THE DENSHAM SURGERY          TS18 1HU   U89141
# 1                   QUEENS PARK MEDICAL CENTRE          TS18 2AW   U07032
# 2                        ACKLAM MEDICAL CENTRE           TS5 8SB   U02671
# 3                           SPRINGWOOD SURGERY          TS14 7DJ   U07842
# 4              TENNANT STREET MEDICAL PRACTICE          TS18 2AT   U07032
# ...                                        ...               ...      ...
# 6522                  WHITEHOUSE HEALTH CENTRE           MK8 1EQ   U58600
# 6523         SHAKESPEARE ROAD MEDICAL PRACTICE          RG24 9DT        U
# 6524      SAS WEST ESSEX COMMISCEO PCS LIMITED           SS2 6BB        U
# 6525               LAMBETH HEALTHCARE PRACTICE          SE21 8AU   U39721
# 6526  NENE VALLEY AND HODGSON MEDICAL PRACTICE           PE2 5GP        U
#
#                              PCN_NAME ONS_CCG_CODE CCG_CODE  \
# 0                        STOCKTON PCN    E38000247      16C
# 1                  NORTH STOCKTON PCN    E38000247      16C
# 2           GREATER MIDDLESBROUGH PCN    E38000247      16C
# 3                  EAST CLEVELAND PCN    E38000247      16C
# 4                  NORTH STOCKTON PCN    E38000247      16C
# ...                               ...          ...      ...
# 6522       WATLING STREET NETWORK PCN    E38000249    M1J4Y
# 6523                      Unallocated    E38000253    D9Y0V
# 6524                      Unallocated    E38000197      07H
# 6525  HILLS, BROOKS & DALES GROUP PCN    E38000244      72Q
# 6526                      Unallocated    E38000026      06H
#
#                                               CCG_NAME ONS_STP_CODE STP_CODE  \
# 0                                  NHS Tees Valley CCG    E54000050      QHM
# 1                                  NHS Tees Valley CCG    E54000050      QHM
# 2                                  NHS Tees Valley CCG    E54000050      QHM
# 3                                  NHS Tees Valley CCG    E54000050      QHM
# 4                                  NHS Tees Valley CCG    E54000050      QHM
# ...                                                ...          ...      ...
# 6522     NHS Bedfordshire, Luton and Milton Keynes CCG    E54000024      QHG
# 6523  NHS Hampshire, Southampton and Isle of Wight CCG    E54000042      QRL
# 6524                                NHS West Essex CCG    E54000025      QM7
# 6525                         NHS South East London CCG    E54000030      QKK
# 6526           NHS Cambridgeshire and Peterborough CCG    E54000021      QUE
#
#                                    STP_NAME ONS_COMM_REGION_CODE  \
# 0                    Cumbria and North East            E40000009
# 1                    Cumbria and North East            E40000009
# 2                    Cumbria and North East            E40000009
# 3                    Cumbria and North East            E40000009
# 4                    Cumbria and North East            E40000009
# ...                                     ...                  ...
# 6522  Bedfordshire, Luton and Milton Keynes            E40000007
# 6523        Hampshire and the Isle of Wight            E40000005
# 6524           Hertfordshire and West Essex            E40000007
# 6525        Our Healthier South East London            E40000003
# 6526        Cambridgeshire and Peterborough            E40000007
#
#      COMM_REGION_CODE          COMM_REGION_NAME
# 0                 Y63  North East and Yorkshire
# 1                 Y63  North East and Yorkshire
# 2                 Y63  North East and Yorkshire
# 3                 Y63  North East and Yorkshire
# 4                 Y63  North East and Yorkshire
# ...               ...                       ...
# 6522              Y61           East of England
# 6523              Y59                South East
# 6524              Y61           East of England
# 6525              Y56                    London
# 6526              Y61           East of England
#
# [6527 rows x 16 columns]

# %%
#load in data and retrieve the number of trusts
df_trusts = pd.read_csv('/Users/muhammad-faaiz.shanawas/Documents/GitHub/SystemHierarchies/data/data_DSPTmetric_20220208.csv')
df_trusts = df_trusts.loc[df_trusts["Sector"] == "Trust"].reset_index(drop = True)
df_trusts_cut = df_trusts[["Code", "Name", "CCG20CD"]]

#df_trusts_cut = df_trusts_cut.rename(columns = {"CCG20CD" : ""})
df_trusts
# Out:
#      Unnamed: 0 Code                                               Name  \
# 0           141  TAD        BRADFORD DISTRICT CARE NHS FOUNDATION TRUST
# 1           142  TAF          CAMDEN AND ISLINGTON NHS FOUNDATION TRUST
# 2           143  TAH  SHEFFIELD HEALTH & SOCIAL CARE NHS FOUNDATION ...
# 3           144  TAJ      BLACK COUNTRY HEALTHCARE NHS FOUNDATION TRUST
# 4           145  R0A         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# ..          ...  ...                                                ...
# 212         353  RYR   UNIVERSITY HOSPITALS SUSSEX NHS FOUNDATION TRUST
# 213         354  RYV        CAMBRIDGESHIRE COMMUNITY SERVICES NHS TRUST
# 214         355  RYW  BIRMINGHAM COMMUNITY HEALTHCARE NHS FOUNDATION...
# 215         356  RYX      CENTRAL LONDON COMMUNITY HEALTHCARE NHS TRUST
# 216         357  RYY         KENT COMMUNITY HEALTH NHS FOUNDATION TRUST
#
#      Postcode       Start Close Sector CCG20CD CCG20NM    STP20CD  ...  \
# 0    BD18 3LD  2002-04-01   NaN  Trust     NaN     NaN  E54000054  ...
# 1     NW1 0PE  2002-04-01   NaN  Trust     NaN     NaN  E54000028  ...
# 2     S10 3TH  2003-04-01   NaN  Trust     NaN     NaN  E54000009  ...
# 3     DY2 8PS  2003-04-01   NaN  Trust     NaN     NaN  E54000016  ...
# 4     M13 9WL  2017-10-01   NaN  Trust     NaN     NaN  E54000007  ...
# ..        ...         ...   ...    ...     ...     ...        ...  ...
# 212  BN11 2DH  2009-04-01   NaN  Trust     NaN     NaN  E54000053  ...
# 213  PE27 4LG  2010-04-01   NaN  Trust     NaN     NaN  E54000021  ...
# 214    B7 4BN  2010-11-01   NaN  Trust     NaN     NaN  E54000017  ...
# 215   NW1 5JD  2010-11-01   NaN  Trust     NaN     NaN  E54000027  ...
# 216  ME16 9NT  2010-11-01   NaN  Trust     NaN     NaN  E54000032  ...
#
#     longitude Successor.Code  \
# 0   -1.788605            NaN
# 1   -0.131658            NaN
# 2   -1.537421            NaN
# 3   -2.084448            NaN
# 4   -2.227711            NaN
# ..        ...            ...
# 212 -0.363429            NaN
# 213 -0.067127            NaN
# 214 -1.885825            NaN
# 215 -0.151539            NaN
# 216  0.478818            NaN
#
#                                      Organisation.Name  \
# 0          BRADFORD DISTRICT CARE NHS FOUNDATION TRUST
# 1            CAMDEN AND ISLINGTON NHS FOUNDATION TRUST
# 2    Sheffield Health & Social Care NHS Foundation ...
# 3        Black Country Healthcare NHS Foundation Trust
# 4           MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# ..                                                 ...
# 212   University Hospitals Sussex NHS Foundation Trust
# 213        Cambridgeshire Community Services NHS Trust
# 214  Birmingham Community Healthcare NHS Foundation...
# 215      Central London Community Healthcare NHS Trust
# 216         Kent Community Health NHS Foundation Trust
#
#                    Latest.Status Date.Of.Publication Primary.Sector  \
# 0       20/21 Standards Exceeded          28/07/2021      NHS Trust
# 1            20/21 Standards Met          27/07/2021      NHS Trust
# 2    20/21 Approaching Standards          01/07/2021      NHS Trust
# 3    20/21 Approaching Standards          30/06/2021      NHS Trust
# 4            20/21 Standards Met          30/06/2021      NHS Trust
# ..                           ...                 ...            ...
# 212          20/21 Standards Met          26/04/2021      NHS Trust
# 213          20/21 Standards Met          30/06/2021      NHS Trust
# 214  20/21 Approaching Standards          29/06/2021      NHS Trust
# 215          20/21 Standards Met          29/06/2021      NHS Trust
# 216          20/21 Standards Met          26/05/2021      NHS Trust
#
#      Commissioner..From.ODS.  Successor.Status                 Final.Status  \
# 0                        NaN               NaN     20/21 Standards Exceeded
# 1                        NaN               NaN          20/21 Standards Met
# 2                        NaN               NaN  20/21 Approaching Standards
# 3                        NaN               NaN  20/21 Approaching Standards
# 4                        NaN               NaN          20/21 Standards Met
# ..                       ...               ...                          ...
# 212                      NaN               NaN          20/21 Standards Met
# 213                      NaN               NaN          20/21 Standards Met
# 214                      NaN               NaN  20/21 Approaching Standards
# 215                      NaN               NaN          20/21 Standards Met
# 216                      NaN               NaN          20/21 Standards Met
#
#               Short.Status
# 0       Standards Exceeded
# 1            Standards Met
# 2    Approaching Standards
# 3    Approaching Standards
# 4            Standards Met
# ..                     ...
# 212          Standards Met
# 213          Standards Met
# 214  Approaching Standards
# 215          Standards Met
# 216          Standards Met
#
# [217 rows x 27 columns]

# %%
#create dict and display funnel chart

data_funnel = dict(number = [7, num_of_stps, num_of_ccgs, num_of_trusts, num_of_pcns, 6528], stage = ["Regions", "ICS", "CCG", "Trusts", "PCN", "GP Practices"])

fig = px.funnel(data_funnel, x= 'number', y = 'stage')
#fig.show()

# %%
#create a sunburst chart mapping regions-stps-ccgs-pcn-practices
print(df_gp_cut)
fig2 = px.sunburst(df_gp_cut, path = ['COMM_REGION_NAME', 'STP_NAME', 'CCG_NAME', 'PCN_NAME', 'PRACTICE_NAME'], values = None)
#fig2.show()

# %%
#create a medium sunburst chart mapping regions-stps-ccgs-trusts
fig3 = px.sunburst(df_gp_cut, path = ['COMM_REGION_NAME', 'STP_NAME', 'CCG_NAME', 'TRUST_NAME'], values = None)
fig3.show()

# %%
#create a smaller sunburst chart mapping regions-stps-ccgs
fig4 = px.sunburst(df_gp_cut, path = ['COMM_REGION_NAME', 'STP_NAME', 'CCG_NAME'], values = None)
#fig4.show()

# %%
#create a treemap mapping regions-stps-ccgs-pcns-practices
fig5= px.treemap(df_gp_cut, path = ['COMM_REGION_NAME', 'STP_NAME', 'CCG_NAME', 'PCN_NAME', 'PRACTICE_NAME'], values = None)
#fig5.show()

# %%
#create a smaller treemap mapping regions-stps-ccgs
fig6 = px.treemap(df_gp_cut, path = ['COMM_REGION_NAME', 'STP_NAME', 'CCG_NAME'], values = None)
#fig6.show()

# %%
#saving all plotly figures
'''
fig.write_html("/Users/muhammad-faaiz.shanawas/Documents/GitHub/SystemHierarchies/map outputs/funnel_chart.html")
fig2.write_html("/Users/muhammad-faaiz.shanawas/Documents/GitHub/SystemHierarchies/map outputs/sunburst_large.html")
fig3.write_html("/Users/muhammad-faaiz.shanawas/Documents/GitHub/SystemHierarchies/map outputs/sunburst_small.html")
fig4.write_html("/Users/muhammad-faaiz.shanawas/Documents/GitHub/SystemHierarchies/map outputs/treemap_large.html")
fig5.write_html("/Users/muhammad-faaiz.shanawas/Documents/GitHub/SystemHierarchies/map outputs/treemap_small.html")
'''
